# %%
import pandas as pd

# %%
collision_df = pd.read_pickle('../data/2019_collisions.pkl')
collision_df = collision_df[collision_df['C_WDAY'] != 'U']
collision_df
# Out:
#         C_YEAR C_MNTH C_WDAY C_HOUR  C_SEV  C_VEHS C_CONF C_RCFG C_WTHR  \
# 0         2019      1      1     11      2       2     32      1      1
# 1         2019      1      1     11      2       2     32      1      1
# 2         2019      1      1     11      2       2     32      1      1
# 3         2019      1      1     11      2       2     32      1      1
# 4         2019      1      1     16      2       2     32      1      2
# ...        ...    ...    ...    ...    ...     ...    ...    ...    ...
# 269321    2019     12      7      8      2       2     21      1      1
# 269322    2019     12      7     23      2       2     35      2      2
# 269323    2019     12      7     23      2       2     35      2      2
# 269324    2019     12      7     23      2       2     35      2      2
# 269325    2019     12      7     22      2       1      4      1      7
#
#        C_RSUR  ... V_TYPE V_YEAR P_ID P_SEX P_AGE P_PSN P_ISEV P_SAFE P_USER  \
# 0           5  ...      1   2015    1     M    56    QQ      1      2      U
# 1           5  ...      1   2015   UU     U    UU    UU      U     UU      U
# 2           5  ...      1   2010    1     F    30    11      2      2      1
# 3           5  ...      1   2010    2     U     1    QQ      N     NN      U
# 4           5  ...      1   2007    1     F    27    11      2      2      1
# ...       ...  ...    ...    ...  ...   ...   ...   ...    ...    ...    ...
# 269321      2  ...      1   2015    2     F    61    13      1      2      2
# 269322      2  ...      1   2016    1     F    39    11      1      2      1
# 269323      2  ...      1   2016    2     M    38    12      2      2      2
# 269324      2  ...      1   2011    1     M    30    11      2      2      1
# 269325      3  ...      1   UUUU    1     F    20    11      2     UU      1
#
#          C_CASE
# 0       2681651
# 1       2681651
# 2       2681651
# 3       2681651
# 4       2681652
# ...         ...
# 269321  2785526
# 269322  2785585
# 269323  2785585
# 269324  2785585
# 269325  2786253
#
# [269326 rows x 23 columns]

# %%
collision_df['C_WDAY'].hist()
# Out:
# <Axes: >
